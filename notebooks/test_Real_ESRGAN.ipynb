# %% [markdown]
# ## Test de Real ESRGAN
#
# Installations

# %%
# Colab ou container docker ? Les deux seules variables de chemin du notebook.
try:
    import google.colab  # noqa: F401
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    DST_DIR = '/content/'   # données
    REAL_DIR = '/content/'  # parent du repo Real-ESRGAN
else:
    DST_DIR = '/datasets/'  # ./docker/jupyter monte DATASET_DIR ici
    REAL_DIR = '/'          # le repo est bind-monté sur /Real-ESRGAN

print(f'IN_COLAB={IN_COLAB} DST_DIR={DST_DIR} REAL_DIR={REAL_DIR}')

# %%
#!git clone https://github.com/Leasgr/Real-ESRGAN
#%cd Real-ESRGAN
# Out:
# Cloning into 'Real-ESRGAN'...
# remote: Enumerating objects: 759, done.
# remote: Total 759 (delta 0), reused 0 (delta 0), pack-reused 759 (from 1)
# Receiving objects: 100% (759/759), 5.39 MiB | 24.73 MiB/s, done.
# Resolving deltas: 100% (408/408), done.

# %%
#!pip -q install basicsr facexlib gfpgan
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 16.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 20.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.7/344.7 kB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 146.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 27.9 MB/s eta 0:00:00
# ...
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214819 sha256=482987f3b2eadc76a0c4a9e0c9aa83d813df6d1373ffd6081674cb735ce6d4c6
# ...

# %%
#!pip install -e ./Real-ESRGAN
# Out:
# Obtaining file:///content/Real-ESRGAN
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for realesrgan
# ...

# %%
#!pip install basicsr facexlib gfpgan
#!pip install -r requirements.txt --break-system-packages
#!python setup.py develop
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 20.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.7/344.7 kB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 139.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 30.1 MB/s eta 0:00:00
# ...
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214818 sha256=e8cce747270be9342f57cb9a5f8c6d042ac1e44c08affd1b17d98c4a3575a4bc
# ...

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q gdown

import shutil

import gdown

# unzip n'est pas installé dans l'image docker -> shutil fait le même travail
for name, file_id in [('patches_out', '1BG0HqDYQZ0hJUwaLLs7LdVWe_liX3iZq'),
                      ('patches_in', '14Z4jAx2YJA3W3pJSV71aHo4KGv-Bpzi_')]:
    zip_path = f'{DST_DIR}{name}.zip'
    gdown.download(f'https://drive.google.com/uc?id={file_id}', zip_path, quiet=False)
    shutil.unpack_archive(zip_path, DST_DIR)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1BG0HqDYQZ0hJUwaLLs7LdVWe_liX3iZq
# From (redirected): https://drive.google.com/uc?id=1BG0HqDYQZ0hJUwaLLs7LdVWe_liX3iZq&confirm=t&uuid=ed8ebc5e-4ecc-4d9a-b833-bc4bfec0af1b
# To: /content/patches_out.zip
# 100%|██████████| 161M/161M [00:04<00:00, 36.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=14Z4jAx2YJA3W3pJSV71aHo4KGv-Bpzi_
# From (redirected): https://drive.google.com/uc?id=14Z4jAx2YJA3W3pJSV71aHo4KGv-Bpzi_&confirm=t&uuid=5130dfcf-d5e4-48a1-844b-d97cbc3847f4
# To: /content/patches_in.zip
# 100%|██████████| 160M/160M [00:03<00:00, 43.6MB/s]

# %%
#import os
#os.makedirs('/content/drive/MyDrive/Stage Léa Sagroun/checkpoints_realesrgan', exist_ok=True)

# %% [markdown]
# Importation des données et filtrage des données avec nuage

# %%
#!unzip -oq "/content/drive/MyDrive/Stage Léa Sagroun/data_brute/patches_out.zip" -d /content

# %%
#!unzip -oq "/content/drive/MyDrive/Stage Léa Sagroun/data_brute/patches_in.zip" -d /content

# %%
import numpy as np
from PIL import Image
import glob
import os

folder = f"{DST_DIR}patches_out"

mask_files = sorted(glob.glob(os.path.join(folder, "*_mask.png")))
print(f"Nombre de masques trouvés : {len(mask_files)}")

for f in mask_files[:5]:
    mask = np.array(Image.open(f))
    print(f"{os.path.basename(f)} -> valeurs uniques : {np.unique(mask)}")

all_values = set()
for f in mask_files:
    mask = np.array(Image.open(f))
    all_values.update(np.unique(mask).tolist())

print(f"\nToutes les valeurs uniques rencontrées dans tous les masques : {sorted(all_values)}")
# Out:
# Nombre de masques trouvés : 1764
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c00000_mask.png -> valeurs uniques : [  0 128 255]
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c00256_mask.png -> valeurs uniques : [  0 128 255]
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c00512_mask.png -> valeurs uniques : [  0 128]
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c00768_mask.png -> valeurs uniques : [  0 128]
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c01024_mask.png -> valeurs uniques : [  0 128]
#
# Toutes les valeurs uniques rencontrées dans tous les masques : [0, 128, 255]

# %%
import numpy as np
from PIL import Image
import glob
import os
import shutil

folder_in = f"{DST_DIR}patches_in"
folder_out = f"{DST_DIR}patches_out"

folder_in_filtered = f"{DST_DIR}patches_in_filtered"
folder_out_filtered = f"{DST_DIR}patches_out_filtered"

os.makedirs(folder_in_filtered, exist_ok=True)
os.makedirs(folder_out_filtered, exist_ok=True)

CLOUD_VALUE = 128

mask_files = sorted(glob.glob(os.path.join(folder_out, "*_mask.png")))
print(f"Nombre de masques trouvés : {len(mask_files)}")

kept = 0
removed = 0

for mask_path in mask_files:
    mask = np.array(Image.open(mask_path))

    has_cloud = CLOUD_VALUE in np.unique(mask)

    mask_filename = os.path.basename(mask_path)
    base_name = mask_filename.replace("_mask.png", "")
    image_filename = base_name + ".png"

    if has_cloud:
        removed += 1
        continue

    kept += 1

    shutil.copy(
        os.path.join(folder_in, image_filename),
        os.path.join(folder_in_filtered, image_filename)
    )
    shutil.copy(
        os.path.join(folder_in, mask_filename),
        os.path.join(folder_in_filtered, mask_filename)
    )

    shutil.copy(
        os.path.join(folder_out, image_filename),
        os.path.join(folder_out_filtered, image_filename)
    )
    shutil.copy(
        os.path.join(folder_out, mask_filename),
        os.path.join(folder_out_filtered, mask_filename)
    )

print(f"\nPatches gardés (sans nuage) : {kept}")
print(f"Patches éliminés (avec nuage) : {removed}")
print(f"\nDossiers créés :")
print(f"  - {folder_in_filtered}")
print(f"  - {folder_out_filtered}")
# Out:
# Nombre de masques trouvés : 1764
#
# Patches gardés (sans nuage) : 1689
# Patches éliminés (avec nuage) : 75
#
# Dossiers créés :
#   - /content/patches_in_filtered
#   - /content/patches_out_filtered

# %%
import random

random.seed(42)

folder_in_filtered = f"{DST_DIR}patches_in_filtered"
folder_out_filtered = f"{DST_DIR}patches_out_filtered"

split_base = f"{DST_DIR}dataset_split"

image_files = sorted([
    f for f in os.listdir(folder_out_filtered)
    if f.endswith(".png") and not f.endswith("_mask.png")
])

random.shuffle(image_files)

n = len(image_files)
n_train = int(0.70 * n)
n_val = int(0.15 * n)
splits = {
    "train": image_files[:n_train],
    "val": image_files[n_train:n_train + n_val],
    "test": image_files[n_train + n_val:],
}

for split_name, files in splits.items():
    for sub in ["patches_in", "patches_out"]:
        os.makedirs(os.path.join(split_base, split_name, sub), exist_ok=True)

for split_name, files in splits.items():
    for image_filename in files:
        base_name = image_filename.replace(".png", "")
        mask_filename = base_name + "_mask.png"

        for sub, src_folder in [("patches_in", folder_in_filtered), ("patches_out", folder_out_filtered)]:
            dst_dir = os.path.join(split_base, split_name, sub)
            shutil.copy(os.path.join(src_folder, image_filename), os.path.join(dst_dir, image_filename))
            shutil.copy(os.path.join(src_folder, mask_filename), os.path.join(dst_dir, mask_filename))

print(f"Total patches : {n}")
print(f"Train : {len(splits['train'])} | Val : {len(splits['val'])} | Test : {len(splits['test'])}")
# Out:
# Total patches : 1689
# Train : 1182 | Val : 253 | Test : 254

# %%
from PIL import Image
import os

split_base = f"{DST_DIR}dataset_split"
splits = ["train", "val", "test"]

for split_name in splits:
    src_dir = os.path.join(split_base, split_name, "patches_out")
    dst_dir = os.path.join(split_base, split_name, "patches_out_128")
    os.makedirs(dst_dir, exist_ok=True)

    count = 0
    for fname in os.listdir(src_dir):
        if fname.endswith(".png") and not fname.endswith("_mask.png"):
            img = Image.open(os.path.join(src_dir, fname)).convert("RGB")
            img_resized = img.resize((128, 128), Image.BICUBIC)
            img_resized.save(os.path.join(dst_dir, fname))
            count += 1

    print(f"{split_name} : {count} images downscalées -> {dst_dir}")
# Out:
# train : 1182 images downscalées -> /content/dataset_split/train/patches_out_128
# val : 253 images downscalées -> /content/dataset_split/val/patches_out_128
# test : 254 images downscalées -> /content/dataset_split/test/patches_out_128

# %%
import os
import shutil

src = f"{DST_DIR}dataset_split/train/patches_in"
dst = f"{DST_DIR}dataset_split/train/patches_in_images"
os.makedirs(dst, exist_ok=True)

count = 0
for fname in os.listdir(src):
    if fname.endswith(".png") and not fname.endswith("_mask.png"):
        shutil.copy(os.path.join(src, fname), os.path.join(dst, fname))
        count += 1

print(f"{count} images copiées (sans masques) -> {dst}")
# Out:
# 1182 images copiées (sans masques) -> /content/dataset_split/train/patches_in_images

# %%
import os

REPO = f"{REAL_DIR}Real-ESRGAN"
TRAIN_DIR = f"{DST_DIR}dataset_split/train"
META_INFO = f"{TRAIN_DIR}/meta_info_train_pair.txt"
os.chdir(REPO)
print(os.getcwd())

# --root est obligatoire : sans lui le script écrit des chemins relatifs au répertoire
# courant (le repo), que dataroot_gt ne sait pas résoudre.
# !python scripts/generate_meta_info_pairdata.py \
    --input {TRAIN_DIR}/patches_in_images {TRAIN_DIR}/patches_out_128 \
    --root {TRAIN_DIR} {TRAIN_DIR} \
    --meta_info {META_INFO}
# Out:
# /Real-ESRGAN
# patches_in_images/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c02816.png, patches_out_128/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c02816.png
# patches_in_images/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c05120.png, patches_out_128/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c05120.png
# patches_in_images/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c05376.png, patches_out_128/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c05376.png
# patches_in_images/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c05888.png, patches_out_128/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c05888.png
# patches_in_images/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c06656.png, patches_out_128/S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c06656.png
# ...

# %%
# !lscpu
# !nvidia-smi
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             39 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      28
#   On-line CPU(s) list:       0-27
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Core(TM) i7-14700F
#     CPU family:              6
#     Model:                   183
#     Thread(s) per core:      2
#     Core(s) per socket:      14
#     Socket(s):               1
#     Stepping:                1
#     BogoMIPS:                4224.00
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology tsc_reliable nonstop_tsc cpuid tsc
# ...

# %%
# !wc -l {META_INFO}
# Out:
# 1182 /content/dataset_split/train/meta_info_train_pair.txt

# %%
# !cat {REPO}/options/finetune_realesrgan_x4plus_pairdata.yml
# Out:
# # general settings
# name: finetune_RealESRGANx4plus_400k_pairdata
# model_type: RealESRGANModel
# scale: 4
# num_gpu: auto
# manual_seed: 0
#
# # USM the ground-truth
# l1_gt_usm: True
# percep_gt_usm: True
# gan_gt_usm: False
#
# high_order_degradation: False # do not use the high-order degradation generation process
#
# # dataset and data loader settings
# datasets:
#   train:
#     name: DIV2K
#     type: RealESRGANPairedDataset
#     dataroot_gt: datasets/DF2K
#     dataroot_lq: datasets/DF2K
#     meta_info: datasets/DF2K/meta_info/meta_info_DIV2K_sub_pair.txt
#     io_backend:
#       type: disk
#
#     gt_size: 256
#     use_hflip: True
#     use_rot: False
#
#     # data loader
#     use_shuffle: true
#     num_worker_per_gpu: 5
#     batch_size_per_gpu: 12
#     dataset_enlarge_ratio: 1
#     prefetch_mode: ~
#
#   # Uncomment these for validation
#   # val:
#   #   name: validation
#   #   type: PairedImageDataset
#   #   dataroot_gt: path_to_gt
# ...

# %% [markdown]
# ## Téléchargement des modèles

# %%
# !wget -nc https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.1/RealESRGAN_x2plus.pth -P {REPO}/experiments/pretrained_models
# Out:
# --2026-08-03 20:53:14--  https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.1/RealESRGAN_x2plus.pth
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget -nc https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.2.3/RealESRGAN_x2plus_netD.pth -P {REPO}/experiments/pretrained_models
# Out:
# --2026-08-03 20:53:24--  https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.2.3/RealESRGAN_x2plus_netD.pth
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ## Modification des paramètres dans le fichier YAML
#
# scale = 2
#
# rajout de network_g: scale sinon scale reste à 4
#
# dataroot_gt et dataroot_lq remplacés par les bons chemins
#
# meta_info : renvoie au fichier généré plus tôt
#
# use_rot = True
#
# total_iter : 5000 pour commencer car pas beaucoup d'images, suffisant pour un premier test
#
# save_checkpoint_freq = 500, pour rester cohérent avec le nombre d'itérations qui a été diminué

# %%
from pathlib import Path

NAME = 'finetune_RealESRGANx2plus_pairdata_lea'
CONFIG = f'{REPO}/options/finetune_realesrgan_x2plus_lea.yml'

Path(CONFIG).write_text(f'''# general settings
name: {NAME}
model_type: RealESRGANModel
scale: 2
num_gpu: auto
manual_seed: 0

l1_gt_usm: True
percep_gt_usm: True
gan_gt_usm: False

high_order_degradation: False

datasets:
  train:
    name: AdjacencyLake
    type: RealESRGANPairedDataset
    dataroot_gt: {TRAIN_DIR}
    dataroot_lq: {TRAIN_DIR}
    meta_info: {META_INFO}
    io_backend:
      type: disk

    gt_size: 256
    use_hflip: True
    use_rot: True

    use_shuffle: true
    num_worker_per_gpu: 5
    batch_size_per_gpu: 4
    dataset_enlarge_ratio: 1
    prefetch_mode: ~

network_g:
  type: RRDBNet
  num_in_ch: 3
  num_out_ch: 3
  num_feat: 64
  num_block: 23
  num_grow_ch: 32
  scale: 2

network_d:
  type: UNetDiscriminatorSN
  num_in_ch: 3
  num_feat: 64
  skip_connection: True

path:
  pretrain_network_g: {REPO}/experiments/pretrained_models/RealESRGAN_x2plus.pth
  param_key_g: params_ema
  strict_load_g: true
  pretrain_network_d: {REPO}/experiments/pretrained_models/RealESRGAN_x2plus_netD.pth
  param_key_d: params
  strict_load_d: true
  resume_state: ~

train:
  ema_decay: 0.999
  optim_g:
    type: Adam
    lr: !!float 1e-4
    weight_decay: 0
    betas: [0.9, 0.99]
  optim_d:
    type: Adam
    lr: !!float 1e-4
    weight_decay: 0
    betas: [0.9, 0.99]

  scheduler:
    type: MultiStepLR
    milestones: [400000]
    gamma: 0.5

  total_iter: 5000
  warmup_iter: -1

  pixel_opt:
    type: L1Loss
    loss_weight: 1.0
    reduction: mean
  perceptual_opt:
    type: PerceptualLoss
    layer_weights:
      'conv1_2': 0.1
      'conv2_2': 0.1
      'conv3_4': 1
      'conv4_4': 1
      'conv5_4': 1
    vgg_type: vgg19
    use_input_norm: true
    perceptual_weight: !!float 1.0
    style_weight: 0
    range_norm: false
    criterion: l1
  gan_opt:
    type: GANLoss
    gan_type: vanilla
    real_label_val: 1.0
    fake_label_val: 0.0
    loss_weight: !!float 1e-1

  net_d_iters: 1
  net_d_init_iters: 0

logger:
  print_freq: 100
  save_checkpoint_freq: !!float 500
  use_tb_logger: true
  wandb:
    project: ~
    resume_id: ~

dist_params:
  backend: nccl
  port: 29500
''')

print(Path(CONFIG).read_text())
# Out:
# Overwriting /Real-ESRGAN/options/finetune_realesrgan_x2plus_lea.yml

# %%
if IN_COLAB:
    # !sed -i 's/from torchvision.transforms.functional_tensor import rgb_to_grayscale/from torchvision.transforms.functional import rgb_to_grayscale/' /usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py
else:
    print('patch functional_tensor déjà appliqué dans l\'image docker')

# %%
os.chdir(REPO)
# !python realesrgan/train.py -opt {CONFIG} --auto_resume
# Out:
# /Real-ESRGAN
# Disable distributed.
# 2026-08-03 20:54:34,501 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.11.0+cu128
# 	TorchVision: 0.26.0+cu128
# 2026-08-03 20:54:34,501 INFO:
#   name: finetune_RealESRGANx2plus_pairdata_lea
#   model_type: RealESRGANModel
#   scale: 2
#   num_gpu: 1
#   manual_seed: 0
#   l1_gt_usm: True
#   percep_gt_usm: True
# ...

# %%
import shutil, os

if IN_COLAB:
    src = f"{REPO}/experiments/{NAME}"
    dst = f"/content/drive/MyDrive/Stage Léa Sagroun/checkpoints_realesrgan/{NAME}"

    os.makedirs(os.path.dirname(dst), exist_ok=True)
    shutil.copytree(src, dst, dirs_exist_ok=True)

    print("Copié avec succès vers Drive :", dst)
else:
    # /Real-ESRGAN est bind-monté : les checkpoints sont déjà sur l'hôte.
    print("Rien à copier, checkpoints dans", f"{REPO}/experiments/{NAME}")
# Out:
# Copié avec succès vers Drive : /content/drive/MyDrive/Stage Léa Sagroun/checkpoints_realesrgan/finetune_RealESRGANx2plus_pairdata_lea

# %% [markdown]
# ## Test
#
# ### Dowscale du test set 128x128

# %%
from PIL import Image
import os

src_dir = f"{DST_DIR}dataset_split/test/patches_out"
dst_dir = f"{DST_DIR}dataset_split/test/patches_out_128"
os.makedirs(dst_dir, exist_ok=True)

count = 0
for fname in os.listdir(src_dir):
    if fname.endswith(".png") and not fname.endswith("_mask.png"):
        img = Image.open(os.path.join(src_dir, fname)).convert("RGB")
        img_resized = img.resize((128, 128), Image.BICUBIC)
        img_resized.save(os.path.join(dst_dir, fname))
        count += 1

print(f"test : {count} images downscalées -> {dst_dir}")
# Out:
# test : 254 images downscalées -> /content/dataset_split/test/patches_out_128

# %% [markdown]
# ### Copie du checkpoint depuis Drive vers le disque local pour l'inférence

# %%
CKPT_SRC = (f"/content/drive/MyDrive/Stage Léa Sagroun/checkpoints_realesrgan/{NAME}/models/net_g_5000.pth"
            if IN_COLAB else f"{REPO}/experiments/{NAME}/models/net_g_5000.pth")
CKPT = f"{REPO}/experiments/pretrained_models/net_g_5000.pth"

assert os.path.exists(CKPT_SRC), f"checkpoint absent : {CKPT_SRC}"
shutil.copy(CKPT_SRC, CKPT)
print(CKPT)

# %%
#Vérification du downscale
# !ls {DST_DIR}dataset_split/test/patches_out_128 | head -5
# !ls {DST_DIR}dataset_split/test/patches_out_128 | wc -l
# Out:
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c04352.png
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c06144.png
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c07936.png
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c08192.png
# S2A_MSIL1C_20230823T154821_N0510_R054_T18TXR_20241025T022611_r00000_c10496.png
# 254

# %% [markdown]
# ### Inférence

# %%
import torch
import numpy as np
from PIL import Image
import os
from basicsr.archs.rrdbnet_arch import RRDBNet
from realesrgan import RealESRGANer

# Chargement du modèle fine-tuné
model = RRDBNet(num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=2)

upsampler = RealESRGANer(
    scale=2,
    model_path=CKPT,
    model=model,
    tile=0,
    tile_pad=10,
    pre_pad=0,
    half=True  # utilise la précision FP16, plus rapide sur GPU
)

test_lq_dir = f"{DST_DIR}dataset_split/test/patches_out_128"
test_gt_dir = f"{DST_DIR}dataset_split/test/patches_in"
output_dir = f"{DST_DIR}dataset_split/test/patches_output_inference"
os.makedirs(output_dir, exist_ok=True)

def calculate_psnr(img1, img2):
    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return float('inf')
    return 20 * np.log10(255.0 / np.sqrt(mse))

psnr_values = []
files = sorted([f for f in os.listdir(test_lq_dir) if f.endswith(".png")])

print(f"Nombre d'images à traiter : {len(files)}")

for i, fname in enumerate(files):
    lq_path = os.path.join(test_lq_dir, fname)
    gt_path = os.path.join(test_gt_dir, fname)

    img_lq = np.array(Image.open(lq_path).convert("RGB"))

    output, _ = upsampler.enhance(img_lq, outscale=2)

    out_path = os.path.join(output_dir, fname)
    Image.fromarray(output).save(out_path)

    img_gt = np.array(Image.open(gt_path).convert("RGB"))

    psnr = calculate_psnr(output, img_gt)
    psnr_values.append(psnr)

    if (i + 1) % 50 == 0:
        print(f"{i+1}/{len(files)} images traitées, PSNR moyen jusqu'ici : {np.mean(psnr_values):.2f} dB")

print(f"\n=== RÉSULTAT FINAL ===")
print(f"PSNR moyen sur le test set ({len(psnr_values)} images) : {np.mean(psnr_values):.2f} dB")
print(f"PSNR min : {np.min(psnr_values):.2f} dB")
print(f"PSNR max : {np.max(psnr_values):.2f} dB")
# Out:
# Nombre d'images à traiter : 254
# 50/254 images traitées, PSNR moyen jusqu'ici : 22.64 dB
# 100/254 images traitées, PSNR moyen jusqu'ici : 22.75 dB
# 150/254 images traitées, PSNR moyen jusqu'ici : 22.59 dB
# 200/254 images traitées, PSNR moyen jusqu'ici : 22.73 dB
# 250/254 images traitées, PSNR moyen jusqu'ici : 22.92 dB
#
# === RÉSULTAT FINAL ===
# PSNR moyen sur le test set (254 images) : 22.94 dB
# PSNR min : 19.26 dB
# PSNR max : 24.92 dB
